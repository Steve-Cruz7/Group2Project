# %%
import numpy as np # We need np to load the npz datasets

# %%
real_data = np.load('data/real_world/malware.npz')
# Real World Data vanilla testing

# %%
# Grabbing Data
train_data = real_data['X_train']
train_labels = real_data['y_train']
test_data = real_data['X_test']
test_labels = real_data['y_test']

# %%
# Reading some of the data
print(train_data)
# Out:
# [[-0.3551001  -0.05321397 -0.02537269 ... -0.0795797   0.06989866
#   -0.10908085]
#  [-0.34442618 -0.05321397 -0.02537269 ... -0.0795797   0.06989866
#   -0.10908085]
#  [-0.28623834 -0.03945309 -0.02351119 ... -0.0795797   0.06989866
#   -0.10908085]
#  ...
#  [-0.34735128 -0.0027574  -0.02437034 ... -0.0795797   0.06989866
#   -0.10908085]
#  [-0.34888983 -0.05321397 -0.02537269 ... -0.0795797   0.06989866
#   -0.10908085]
#  [-0.35121906 -0.048627   -0.02537269 ... -0.0795797   0.06989866
#   -0.10908085]]

# %%
# Very vanilla MLP
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(hidden_layer_sizes = (512, 256)) # activation function is relu and optimizer is adam, default loss is cross entropy

# %%
mlp.fit(train_data, train_labels)
# Out:
# MLPClassifier(hidden_layer_sizes=(512, 256))

# %%
predictions = mlp.predict(test_data)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_labels, predictions)
# Out:
# 0.915

# %%
clean_real_data = np.load('data/real_world/malware_true.npz')
true_train_data = data['X_train']
true_train_labels = data['y_train']
true_test_data = data['X_test']
true_test_labels = data['y_test']

# %%
mlp_true = MLPClassifier(hidden_layer_sizes = (512, 256))
mlp.fit(true_train_data, true_train_labels)
# Out:
# MLPClassifier(hidden_layer_sizes=(512, 256))

# %%
predictions = mlp.predict(true_test_data)
accuracy_score(true_test_labels, predictions)
# Out:
# 0.9166666666666666

# %%
from sklearn.metrics import precision_score
precision_score(true_test_labels, predictions, average = None)
# Out:
# array([0.72173913, 0.99009901, 0.98      , 0.92380952, 0.72932331,
#        0.99009901, 0.98969072, 1.        , 0.91588785, 0.96153846,
#        0.96078431, 0.94285714])

# %%
# Very weird, a vanilla MLP is doing pretty damn well against this so called real world data

# %%
syn_data = np.load('data/real_world/malware_true.npz')
syn_train_data = syn_data['X_train']
syn_train_labels = syn_data['y_train']
syn_test_data = syn_data['X_test']
syn_test_labels = syn_data['y_test']

# %%
mlp_syn = MLPClassifier(hidden_layer_sizes = (512, 256))
mlp.fit(syn_train_data, syn_train_labels)
# Out:
# MLPClassifier(hidden_layer_sizes=(512, 256))

# %%
predictions = mlp.predict(syn_test_data)
accuracy_score(syn_test_labels, predictions)
# Out:
# 0.9425
